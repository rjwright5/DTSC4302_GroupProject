# %% [markdown]
# Stress Level Prediction

# %%
# Import dependencies

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Stress Level Prediction Dataset
df = pd.read_csv(r"C:\Users\crowd\Downloads\DTSC 4301 Datasets\Stress Level Prediction\stress_detection_data.csv")

# %%
# Summary of the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 773 entries, 0 to 772
# Data columns (total 22 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Age                  773 non-null    int64
#  1   Gender               773 non-null    object
#  2   Occupation           773 non-null    object
#  3   Marital_Status       773 non-null    object
#  4   Sleep_Duration       773 non-null    float64
#  5   Sleep_Quality        773 non-null    float64
#  6   Wake_Up_Time         773 non-null    object
#  7   Bed_Time             773 non-null    object
#  8   Physical_Activity    773 non-null    float64
#  9   Screen_Time          773 non-null    float64
#  10  Caffeine_Intake      773 non-null    int64
#  11  Alcohol_Intake       773 non-null    int64
#  12  Smoking_Habit        773 non-null    object
#  13  Work_Hours           773 non-null    int64
#  14  Travel_Time          773 non-null    float64
# ...

# %%
#Checking dataset
df.head(10)
# Out:
#    Age  Gender         Occupation Marital_Status  Sleep_Duration  \
# 0   30    Male  Software Engineer         Single             7.0
# 1   35  Female  Marketing Manager        Married             6.0
# 2   40    Male     Data Scientist       Divorced             7.0
# 3   35    Male  Software Engineer         Single             7.0
# 4   29  Female            Teacher         Single             8.0
# 5   45    Male             Doctor        Married             6.0
# 6   32  Female   Graphic Designer         Single             7.0
# 7   37    Male     Civil Engineer        Married             7.5
# 8   50    Male     Business Owner        Married             5.5
# 9   40  Female              Nurse       Divorced             6.0
#
#    Sleep_Quality Wake_Up_Time  Bed_Time  Physical_Activity  Screen_Time  ...  \
# 0            4.0      7:00 AM  10:00 PM                2.0          4.0  ...
# 1            3.0      6:00 AM  11:00 PM                1.0          3.0  ...
# ...

# %%
#Dropping unnecessary Female Variables from the Gender column
df = df[df['Gender'] != 'Female']

# %%
#Checking updated dataset
df.head(10)
# Out:
#     Age Gender          Occupation Marital_Status  Sleep_Duration  \
# 0    30   Male   Software Engineer         Single             7.0
# 2    40   Male      Data Scientist       Divorced             7.0
# 3    35   Male   Software Engineer         Single             7.0
# 5    45   Male              Doctor        Married             6.0
# 7    37   Male      Civil Engineer        Married             7.5
# 8    50   Male      Business Owner        Married             5.5
# 10   34   Male  Software Developer         Single             6.5
# 12   42   Male           Architect        Married             5.0
# 14   38   Male              Lawyer         Single             7.0
# 16   43   Male            Engineer        Married             7.0
#
#     Sleep_Quality Wake_Up_Time  Bed_Time  Physical_Activity  Screen_Time  ...  \
# 0             4.0      7:00 AM  10:00 PM                2.0          4.0  ...
# 2             4.0      7:00 AM  10:00 PM                2.0          4.0  ...
# ...

# %%
# Check for missing values
print(df.isnull().sum())
# Out:
# Age                    0
# Gender                 0
# Occupation             0
# Marital_Status         0
# Sleep_Duration         0
# Sleep_Quality          0
# Wake_Up_Time           0
# Bed_Time               0
# Physical_Activity      0
# Screen_Time            0
# Caffeine_Intake        0
# Alcohol_Intake         0
# Smoking_Habit          0
# Work_Hours             0
# Travel_Time            0
# Social_Interactions    0
# Meditation_Practice    0
# Exercise_Type          0
# Blood_Pressure         0
# Cholesterol_Level      0
# Blood_Sugar_Level      0
# Stress_Detection       0
# dtype: int64
